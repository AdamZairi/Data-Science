# %%
# Exploratory Data Analysis [EDA]
# Exploratory Data Analysis refers to the critical process of
# performing initial investigations on data so as to discover patterns,
# to spot anomalies,to test hypothesis and to check assumptions
# with the help of summary statistics and graphical representations.
 
# It is a good practice to understand the data first and try to gather
# as many insights from it.
 
# Exploratory data analysis (EDA) is used by data scientists to analyze
# and investigate data sets and summarize their main characteristics,
# often employing data visualization methods.
 
# The main purpose of EDA is to help look at data before making any
# assumptions. It can help identify obvious errors, as well as better
# understand patterns within the data, detect outliers or
# anomalous events, find interesting relations among the variables.
 
# DATASET : https://raw.githubusercontent.com/harshbg/Telecom-Churn-Data-Analysis/master/Telecom%20Churn.csv

# %%
# Import all the neccesary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Importing the dataset
data = pd.read_csv('https://raw.githubusercontent.com/harshbg/Telecom-Churn-Data-Analysis/master/Telecom%20Churn.csv')
data
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
# to display the max no. of rows and columns
#pd.options.display.max_columns = None
#pd.options.display.max_rows = None

# %%
# head()
# is used to display the first couple of obeservations
# observations = data

data.head(10)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
# 5    AL             118        510     391-8027                yes
# 6    MA             121        510     355-9993                 no
# 7    MO             147        415     329-9001                yes
# 8    LA             117        408     335-4719                 no
# 9    WV             141        415     330-8173                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# ...

# %%
# tail()
# is used to display the last couple of observations

data.tail()
# Out:
#      state  account length  area code phone number international plan  \
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 3328             yes                     36              156.2
# 3329              no                      0              231.1
# 3330              no                      0              180.8
# 3331              no                      0              213.8
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 3328               77             26.55  ...              126
# ...

# %%
# .columns
# retrieves all of the column names

data.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
# .shape
# prints the dimension of the DataFrame

data.shape
# Out:
# (3333, 21)

# %%
# .index
# prints the range of the DataFrame

data.index
# Out:
# RangeIndex(start=0, stop=3333, step=1)

# %%
# .info
# provides a complete summary of the dataset.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
# converting the data type of a column

data['churn']=data['churn'].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
# .describe()
# used to display the statistical values of the numerical datas

data.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
# to view to statistical summary of non numerical features
# use the include parameter

data.describe(include=['object'])
# Out:
#        state phone number international plan voice mail plan
# count   3333         3333               3333            3333
# unique    51         3333                  2               2
# top       WV     382-4657                 no              no
# freq     106            1               3010            2411

# %%
# value_counts()
# returns a series containing the count of unique values

data['area code'].value_counts()
# Out:
# area code
# 415    1655
# 510     840
# 408     838
# Name: count, dtype: int64

# %%
sns.countplot(x='area code',data=data)
plt.title('Area Code Count')
plt.show()

# %%
# Missing Value calculation
# isnull(0 is used to identify the null values in a dataset.
# returns True if found any missing value

data.isnull()
# Out:
#       state  account length  area code  phone number  international plan  \
# 0     False           False      False         False               False
# 1     False           False      False         False               False
# 2     False           False      False         False               False
# 3     False           False      False         False               False
# 4     False           False      False         False               False
# ...     ...             ...        ...           ...                 ...
# 3328  False           False      False         False               False
# 3329  False           False      False         False               False
# 3330  False           False      False         False               False
# 3331  False           False      False         False               False
# 3332  False           False      False         False               False
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
# the sum of is.null() for every column

data.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
# .duplicated()
# check for duplicate data

data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data['phone number'].duplicated().sum()
# Out:
# np.int64(0)

# %%
# selecting a DataFrame

# Selecting only 1 column
data['phone number'].head(10)
# Out:
# 0    382-4657
# 1    371-7191
# 2    358-1921
# 3    375-9999
# 4    330-6626
# 5    391-8027
# 6    355-9993
# 7    329-9001
# 8    335-4719
# 9    330-8173
# Name: phone number, dtype: object

# %%
# for more than 1 column
data[['phone number','international plan']].head(10)
# Out:
#   phone number international plan
# 0     382-4657                 no
# 1     371-7191                 no
# 2     358-1921                 no
# 3     375-9999                yes
# 4     330-6626                yes
# 5     391-8027                yes
# 6     355-9993                 no
# 7     329-9001                yes
# 8     335-4719                 no
# 9     330-8173                yes

# %%
sns.countplot(x='churn',data=data)
plt.title('Churn Users Count')
plt.show()

# %%
data[['phone number','international plan','churn']].head(50)
# Out:
#    phone number international plan  churn
# 0      382-4657                 no      0
# 1      371-7191                 no      0
# 2      358-1921                 no      0
# 3      375-9999                yes      0
# 4      330-6626                yes      0
# 5      391-8027                yes      0
# 6      355-9993                 no      0
# 7      329-9001                yes      0
# 8      335-4719                 no      0
# 9      330-8173                yes      0
# 10     329-6603                 no      1
# 11     344-9403                 no      0
# 12     363-1107                 no      0
# 13     394-8006                 no      0
# 14     366-9238                 no      0
# 15     351-7269                 no      1
# 16     350-8884                 no      0
# 17     386-2923                 no      0
# 18     356-2992                 no      0
# 19     373-2782                 no      0
# 20     396-5800                 no      0
# ...

# %%
data['customer service calls'] >= 4.
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: customer service calls, Length: 3333, dtype: bool

# %%
# filetring a DataFrame based on conditions set

data[data['customer service calls'] >= 4][['phone number','churn']].head(10)
# Out:
#    phone number  churn
# 10     329-6603      1
# 14     366-9238      0
# 15     351-7269      1
# 21     393-7984      1
# 48     398-1294      1
# 54     353-3759      1
# 69     374-8042      1
# 77     360-1171      1
# 86     402-1251      1
# 97     327-3954      0

# %%
data[data['customer service calls'] >= 4]['churn'].value_counts()
# Out:
# churn
# 1    138
# 0    129
# Name: count, dtype: int64

# %%
data[['phone number','total day charge','churn']].head(5)
# Out:
#   phone number  total day charge  churn
# 0     382-4657             45.07      0
# 1     371-7191             27.47      0
# 2     358-1921             41.38      0
# 3     375-9999             50.90      0
# 4     330-6626             28.34      0

# %%
# Sorting
# sort_values()

data.sort_values(by = 'total day calls',ascending=False).head(10)
# Out:
#      state  account length  area code phone number international plan  \
# 1121    MI              91        415     390-7930                 no
# 468     AZ              86        415     392-2381                 no
# 1460    MT              80        415     361-8288                 no
# 2392    WY              90        510     400-8069                 no
# 1057    WV              86        415     332-2258                 no
# 315     MA              39        408     332-2462                 no
# 2394    IN              57        415     345-5089                 no
# 1869    MS             101        408     387-5533                 no
# 1719    AZ             100        415     333-2337                 no
# 580     IN             113        415     353-6007                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 1121              no                      0              154.4
# 468              yes                     32               70.9
# ...

# %%
data.sort_values(by = 'total night minutes',ascending=False).head(10)
# Out:
#      state  account length  area code phone number international plan  \
# 2663    VA             172        510     408-2089                 no
# 1317    NE              89        415     420-6414                 no
# 1445    ID              55        510     331-7342                 no
# 2321    AR             153        408     339-3636                 no
# 3107    GA              73        408     385-6952                 no
# 922     WI              80        415     398-5006                 no
# 244     VA             108        408     335-1697                 no
# 1238    OH             147        415     365-5682                yes
# 3060    LA              94        415     371-3236                 no
# 2754    IN              96        415     383-4641                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 2663              no                      0              169.8
# 1317             yes                     29              163.5
# ...

# %%
data.sort_values(by = 'total eve minutes',ascending=False).head(10)
# Out:
#      state  account length  area code phone number international plan  \
# 2732    NC             130        408     384-4938                yes
# 2331    IN              46        415     368-9751                 no
# 2551    MD             102        415     386-9774                 no
# 8       LA             117        408     335-4719                 no
# 1601    AR              99        510     387-2604                yes
# 302     RI             121        408     329-7347                 no
# 6       MA             121        510     355-9993                 no
# 580     IN             113        415     353-6007                 no
# 3075    CO             181        510     370-9592                 no
# 2160    NV              94        408     351-4025                yes
#
#      voice mail plan  number vmail messages  total day minutes  \
# 2732              no                      0              216.2
# 2331             yes                     34              191.4
# ...

# %%
# how much on an average active users spend on phone during day time
print('active users spend on phone during day time : ',data[data['churn']==0]['total day minutes'].mean())

# how much on an average churn users spend on phone during day time
print('churn users spend on phone during day time : ',data[data['churn']==1]['total day minutes'].mean())

# how much on an average active users spend on phone during eve and night time
print('active users spend on phone during eve time : ',data[data['churn']==0]['total eve minutes'].mean())
print('active users spend on phone during night time : ',data[data['churn']==0]['total night minutes'].mean())

# how much on an average churn users spend on phone during eve and night time
print('churn users spend on phone during eve time : ',data[data['churn']==0]['total eve minutes'].mean())
print('churn users spend on phone during night time : ',data[data['churn']==0]['total night minutes'].mean())
# Out:
# active users spend on phone during day time :  175.1757543859649
# churn users spend on phone during day time :  206.91407867494823
# active users spend on phone during eve time :  199.043298245614
# active users spend on phone during night time :  200.13319298245614
# churn users spend on phone during eve time :  199.043298245614
# churn users spend on phone during night time :  200.13319298245614

# %%
print(f"average CHURN user spend on phone during EVE time : {data[data['churn']==1]['total eve minutes'].mean():.0f} minutes")
print(f"average CHURN user spend on phone during NIGHT time : {data[data['churn']==1]['total night minutes'].mean():.0f} minutes")
# Out:
# average CHURN user spend on phone during EVE time : 212 minutes
# average CHURN user spend on phone during NIGHT time : 205 minutes

# %%
# grouping

data.groupby(['churn'])['total day minutes'].mean()
# Out:
# churn
# 0    175.175754
# 1    206.914079
# Name: total day minutes, dtype: float64

# %%
columngp = ['total day minutes','total eve minutes','total night minutes']
data.groupby(['churn'])[columngp].mean()
# Out:
#        total day minutes  total eve minutes  total night minutes
# churn
# 0             175.175754         199.043298           200.133193
# 1             206.914079         212.410145           205.231677

# %%
plt.figure(figsize=(15,5))
x = data[data['churn']==0]['total day minutes']
y = data[data['churn']==1]['total day minutes']
plt.plot(x,color='red')
plt.plot(y,color='blue')
plt.xlabel('Customer Index', fontsize=12)
plt.ylabel('Total Day Minutes', fontsize=12)
plt.title('Total Day Minutes by Churn Status', fontsize=16, fontweight='bold')
plt.legend(['Churn=0','Churn=1'])
plt.show()
